# %%
import requests
from bs4 import BeautifulSoup

def get_webpage_content(url):
    try:
        # 发送HTTP GET请求到指定的URL
        response = requests.get(url)
        
        # 检查请求是否成功（状态码200表示成功）
        if response.status_code == 200:
            # 将网页内容解析为BeautifulSoup对象
            soup = BeautifulSoup(response.content, 'html.parser')
            
            # 返回解析后的内容
            return soup
        else:
            print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
            return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
url = "http://10.15.89.177:8899/gpu"  # 替换为你想要解析的URL
soup = get_webpage_content(url)

if soup:
    print(soup.prettify())  # 打印出网页内容的结构化表示
# Out:
# <!DOCTYPE html>
# <html lang="zh_CN">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Docutils 0.17.1: http://docutils.sourceforge.net/" name="generator"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="Copy to clipboard" name="lang:clipboard.copy"/>
#   <meta content="Copied to clipboard" name="lang:clipboard.copied"/>
#   <meta content="en" name="lang:search.language"/>
#   <meta content="True" name="lang:search.pipeline.stopwords"/>
#   <meta content="True" name="lang:search.pipeline.trimmer"/>
#   <meta content="No matching documents" name="lang:search.result.none"/>
#   <meta content="1 matching document" name="lang:search.result.one"/>
#   <meta content="# matching documents" name="lang:search.result.other"/>
#   <meta content="[\s\-]+" name="lang:search.tokenizer"/>
#   <link crossorigin="" href="https://fonts.gstatic.com/" rel="preconnect"/>
#   <link href="https://fonts.googleapis.com/css?family=Roboto+Mono:400,500,700|Roboto:300,400,400i,700&amp;display=fallback" rel="stylesheet"/>
#   <!--<meta http-equiv="refresh" content="1">-->
#   <!-- 新 Bootstrap 核心 CSS 文件 -->
#   <!-- jQuery文件。务必在bootstrap.min.js 之前引入 -->
#   <script src="static/js/jquery.min.js">
#   </script>
#   <!-- 最新的 Bootstrap 核心 JavaScript 文件 -->
#   <script src="static/js/bootstrap.min.js">
#   </script>
#   <link href="static/css/github-markdown.min.css" rel="stylesheet"/>
#   <link href="static/css/bootstrap.min.css" rel="stylesheet"/>
#   <script>
#    function getCookie(name) {
# var r = document.cookie.match("\\b" + name + "=([^;]*)\\b");
# return r ? r[1] : undefined;
# }
# function clear_card(hostname, card_id) {
# document.getElementById("clear-btn-" + hostname + "-" + card_id).setAttribute("disabled", true);
# $.ajax({
# type: "POST",
# url: "/gpu",
# dataType: 'json',
# data: {
# 'hostname': hostname,
# 'card_id': card_id,
# '_xsrf': getCookie("_xsrf"),
# },
# success: function (data) {
# // alert("clear " + card_id + " on " + hostname + " successful!!");
# document.getElementById("clear-btn-" + hostname + "-" + card_id).removeAttribute('enabled');
# location.reload();
# }
# });
# }
#   </script>
#   <style>
#    body,
# input {
# font-family: "Roboto", "Helvetica Neue", Helvetica, Arial, sans-serif
# }
# code,
# kbd,
# pre {
# font-family: "Roboto Mono", "Courier New", Courier, monospace
# }
# .process.label {
# font-size: 80%;
# font-weight: normal;
# color: #e3e9ee;
# padding-top: 2px;
# padding-bottom: 3px;
# line-height: 22px;
# }
# .process.label-warning {
# background-color: #9398a8;
# }
# .process.label-danger {
# background-color: #d86767;
# }
# .process.label-primary {
# background-color: #4b87bb;
# }
# .label .badge {
# background-color: #fff;
# padding: 1px 4px;
# }
# .badge.badge-outline {
# background-color: transparent;
# border: 1px solid;
# color:#7c808d;
# }
# .label-primary .badge {
# color: #3379b7;
# }
# .label-warning .badge {
# color: #7c808d;
# }
# .label-danger .badge {
# color: #db5f5f;
# }
# .th-machine {
# width: 198px;
# }
# .th-machine h2 {
# margin: -8px 15px 0 0;
# display: inline;
# }
# .th-machine small {
# font-size: 90%;
# color: #777;
# font-weight: 400;
# }
# .title-table th {
# border-top-width: 3px !important;
# }
# .title-table {
# margin-top: 40px;
# }
# .th-id {
# width: 18px;
# }
# .th-clear {
# width: 70px;
# }
# .th-name {
# width: 180px;
# }
# .th-mem {
# width: 130px;
# }
# .th-usage {
# width: 130px;
# }
# td .progress {
# margin: 0;
# }
# td .progress.progress-success {
# background-color: #deedde;
# }
# td .progress.progress-warning {
# background-color: #f8eed3;
# }
# td .progress.progress-danger {
# background-color: #f3dedd;
# }
# .process .user {
# font-weight: bold;
# color: #fff;
# }
# h1 small, h2 small {
# font-size: 50%;
# }
# h2 small .label-danger {
# font-size: 80%;
# }
# .btn-process {
# font-size: 10px;
# padding: 1px 3px 0px;
# vertical-align: top;
# }
# .popover-content {
# padding: 1px 5px 4px;
# }
# .btn-xs {
# padding: 1px 5px;
# font-size: 8px;
# line-height: 1.2;
# border-radius: 3px
# }
#   </style>
#   <link href="static/stylesheets/application.css" rel="stylesheet">
#    <link href="static/stylesheets/application-palette.css" rel="stylesheet">
#     <link href="static/stylesheets/application-fixes.css" rel="stylesheet">
#      <link href="static/fonts/material-icons.css" rel="stylesheet">
#       <meta content="#3f51b5" name="theme-color"/>
#       <script src="static/javascripts/modernizr.js">
#       </script>
#       <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-190329530-1">
#       </script>
#       <script>
#        window.dataLayer = window.dataLayer || [];
# function gtag() {
# dataLayer.push(arguments);
# }
# gtag('js', new Date());
# gtag('config', 'UA-190329530-1');
#       </script>
#       <title>
#        信息学院AI Cluster用户手册 — 信息学院AI Cluster用户手册 文档
#       </title>
#       <link href="static/pygments.css" rel="stylesheet" type="text/css"/>
#       <link href="static/material.css" rel="stylesheet" type="text/css"/>
#       <link href="static/copybutton.css" rel="stylesheet" type="text/css"/>
#       <script data-url_root="./" id="documentation_options" src="static/documentation_options.js">
#       </script>
#       <script src="static/jquery.js">
#       </script>
#       <script src="static/underscore.js">
#       </script>
#       <script src="static/doctools.js">
#       </script>
#       <script src="static/clipboard.min.js">
#       </script>
#       <script src="static/copybutton.js">
#       </script>
#       <script src="static/translations.js">
#       </script>
#       <link href="static/favicon.png" rel="shortcut icon"/>
#       <link href="genindex.html" rel="index" title="索引"/>
#       <link href="search.html" rel="search" title="搜索"/>
#       <link href="quickstart/index.html" rel="next" title="了解新集群"/>
#      </link>
#     </link>
#    </link>
#   </link>
#  </head>
#  <body data-md-color-accent="light-blue" data-md-color-primary="#4000FF" dir="ltr">
#   <svg class="md-svg">
#    <defs data-children-count="0">
#     <svg height="448" id="__github" viewbox="0 0 416 448" width="416" xmlns="http://www.w3.org/2000/svg">
#      <path d="M160 304q0 10-3.125 20.5t-10.75 19T128 352t-18.125-8.5-10.75-19T96 304t3.125-20.5 10.75-19T128 256t18.125 8.5 10.75 19T160 304zm160 0q0 10-3.125 20.5t-10.75 19T288 352t-18.125-8.5-10.75-19T256 304t3.125-20.5 10.75-19T288 256t18.125 8.5 10.75 19T320 304zm40 0q0-30-17.25-51T296 232q-10.25 0-48.75 5.25Q229.5 240 208 240t-39.25-2.75Q130.75 232 120 232q-29.5 0-46.75 21T56 304q0 22 8 38.375t20.25 25.75 30.5 15 35 7.375 37.25 1.75h42q20.5 0 37.25-1.75t35-7.375 30.5-15 20.25-25.75T360 304zm56-44q0 51.75-15.25 82.75-9.5 19.25-26.375 33.25t-35.25 21.5-42.5 11.875-42.875 5.5T212 416q-19.5 0-35.5-.75t-36.875-3.125-38.125-7.5-34.25-12.875T37 371.5t-21.5-28.75Q0 312 0 260q0-59.25 34-99-6.75-20.5-6.75-42.5 0-29 12.75-54.5 27 0 47.5 9.875t47.25 30.875Q171.5 96 212 96q37 0 70 8 26.25-20.5 46.75-30.25T376 64q12.75 25.5 12.75 54.5 0 21.75-6.75 42 34 40 34 99.5z" fill="currentColor">
#      </path>
#     </svg>
#    </defs>
#   </svg>
#   <input class="md-toggle" data-md-toggle="drawer" id="__drawer" type="checkbox"/>
#   <input class="md-toggle" data-md-toggle="search" id="__search" type="checkbox"/>
#   <label class="md-overlay" data-md-component="overlay" for="__drawer">
#   </label>
#   <a class="md-skip" href="#index" tabindex="1">
#    Skip to content
#   </a>
#   <header class="md-header" data-md-component="header">
#    <nav class="md-header-nav md-grid">
#     <div class="md-flex navheader">
#      <div class="md-flex__cell md-flex__cell--shrink">
#       <a class="md-header-nav__button md-logo" href="#" title="信息学院AI Cluster用户手册 文档">
#        <img alt="信息学院AI Cluster用户手册 文档 logo" height="26" src="static/logos.png"/>
#       </a>
#      </div>
#      <div class="md-flex__cell md-flex__cell--shrink">
#       <label class="md-icon md-icon--menu md-header-nav__button" for="__drawer">
#       </label>
#      </div>
#      <div class="md-flex__cell md-flex__cell--stretch">
#       <div class="md-flex__ellipsis md-header-nav__title" data-md-component="title">
#        <span class="md-header-nav__topic">
#         AI Cluster用户手册
#        </span>
#        <span class="md-header-nav__topic">
#         信息学院AI Cluster用户手册
#        </span>
#       </div>
#      </div>
#      <div class="md-flex__cell md-flex__cell--shrink">
#       <label class="md-icon md-icon--search md-header-nav__button" for="__search">
#       </label>
#       <div class="md-search" data-md-component="search" role="dialog">
#        <label class="md-search__overlay" for="__search">
#        </label>
#        <div class="md-search__inner" role="search">
#         <form action="search.html" class="md-search__form" method="get" name="search">
#          <input autocapitalize="off" autocomplete="off" class="md-search__input" data-md-component="query" data-md-state="active" name="q" placeholder="Search" spellcheck="false" type="text"/>
#          <label class="md-icon md-search__icon" for="__search">
#          </label>
#          <button class="md-icon md-search__icon" data-md-component="reset" tabindex="-1" type="reset">
#           
#          </button>
#         </form>
#         <div class="md-search__output">
#          <div class="md-search__scrollwrap" data-md-scrollfix="">
#           <div class="md-search-result" data-md-component="result">
#            <div class="md-search-result__meta">
#             Type to start searching
#            </div>
#            <ol class="md-search-result__list">
#            </ol>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <script src="static/javascripts/version_dropdown.js">
#      </script>
#      <script>
#       var json_loc = ""versions.json"",
# target_loc = "../",
# text = "Versions";
# $( document ).ready( add_version_dropdown(json_loc, target_loc, text));
#      </script>
#     </div>
#    </nav>
#   </header>
#   <div class="md-container">
#    <nav class="md-tabs" data-md-component="tabs">
#     <div class="md-tabs__inner md-grid">
#      <ul class="md-tabs__list">
#       <li class="md-tabs__item">
#        <a class="md-tabs__link" href="http://10.15.89.177:9000">
#         信息学院AI Cluster用户手册 文档
#        </a>
#       </li>
#      </ul>
#     </div>
#    </nav>
#    <main class="md-main">
#     <div class="md-main__inner md-grid" data-md-component="container">
#      <div class="md-sidebar md-sidebar--primary" data-md-component="navigation">
#       <div class="md-sidebar__scrollwrap">
#        <div class="md-sidebar__inner">
#         <nav class="md-nav md-nav--primary" data-md-level="0">
#          <label class="md-nav__title md-nav__title--site" for="__drawer">
#           <a class="md-nav__button md-logo" href="#" title="信息学院AI Cluster用户手册 文档">
#            <img alt=" logo" height="48" src="static/logos.png" width="48"/>
#           </a>
#           <a href="http://10.15.89.177:8889" title="信息学院AI Cluster用户手册 文档">
#            AI Cluster用户手册
#           </a>
#          </label>
#          <ul class="md-nav__list">
#           <li class="md-nav__item">
#            <a class="md-nav__link" href="http://10.15.89.177:8889/quickstart/index.html">
#             了解新集群
#            </a>
#           </li>
#           <li class="md-nav__item">
#            <a class="md-nav__link" href="http://10.15.89.177:8889/system/index.html">
#             系统与资源
#            </a>
#           </li>
#           <li class="md-nav__item">
#            <a class="md-nav__link" href="http://10.15.89.177:8889/accounts/index.html">
#             帐号和权限
#            </a>
#           </li>
#           <li class="md-nav__item">
#            <a class="md-nav__link" href="http://10.15.89.177:8889/login/index.html">
#             登录
#            </a>
#           </li>
#           <li class="md-nav__item">
#            <a class="md-nav__link" href="http://10.15.89.177:8889/job/index.html">
#             作业
#            </a>
#           </li>
#           <li class="md-nav__item">
#            <a class="md-nav__link" href="http://10.15.89.177:8889/app/index.html">
#             软件
#            </a>
#           </li>
#           <li class="md-nav__item">
#            <a class="md-nav__link" href="http://10.15.89.177:8889/team/index.html">
#             联系我们
#            </a>
#           </li>
#           <li class="md-nav__item">
#            <a class="md-nav__link" href="http://10.15.89.177:8889/Q%26A/index.html">
#             Q&amp;A
#            </a>
#           </li>
#           <li class="md-nav__item">
#            <a class="md-nav__link md-nav__link--active" href="http://10.15.89.177:8899/gpu">
#             实时GPU使用情况
#            </a>
#           </li>
#          </ul>
#         </nav>
#        </div>
#       </div>
#      </div>
#      <div class="md-sidebar md-sidebar--secondary" data-md-component="toc">
#       <div class="md-sidebar__scrollwrap">
#        <div class="md-sidebar__inner">
#         <nav class="md-nav md-nav--secondary">
#          <ul class="md-nav__list" data-md-scrollfix="">
#          </ul>
#         </nav>
#        </div>
#       </div>
#      </div>
#      <div class="md-content">
#       <article class="md-content__inner md-typeset" role="main">
#        <section id="ai-cluster">
#         <div class="container">
#          <div class="row clearfix">
#           <h2>
#            信息学院AI集群(NEW,10.15.89.191/192)
#           </h2>
#           <h3>
#            （注意仅显示公用节点使用情况,每分钟刷新一次）
#           </h3>
#           <h3>
#            注意，本页面显示的是运行情况，GPU空闲不代表资源空闲，请在队列中查看具体的资源分配情况
#           </h3>
#           <h3>
#            ****为了进一步提高集群使用效率，目前已经启用自动清理释放资源的脚本，申请GPU资源但持续空闲时间超过一小时（使用率长期低于5%视作空闲）的任务将被自动清理。
#            <h3>
#             <h4>
#              ai_gpu01
#              <small>
#               2024-09-21 15:36:02
#              </small>
#              (CPU:14.23% [12/80] MEM:54G/502G)
#             </h4>
#             <table class="table table-striped table-condensed">
#              <tr>
#               <th class="th-id">
#                #
#               </th>
#               <th class="th-name">
#                Name
#               </th>
#               <th class="th-mem">
#                Memory
#               </th>
#               <th class="th-usage">
#                GPU
#               </th>
#               <th class="th-processes">
#                <span class="hidden-xs">
#                 Processes
#                 <span class="label label-default">
#                  pid@user (RAM)
#                 </span>
#                </span>
#               </th>
#              </tr>
#              <tr>
#               <td>
#                0
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA A40
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="4259/46068">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 9%">
#                  9%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="71 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 90%">
#                  90%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python Mem: 3804 Mib &lt;br/&gt; 运行时间: 04小时49分钟57秒">
#                  220632@
#                  <span class="user">
#                   liuzhh2023
#                  </span>
#                  (8%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
#                  <i class="glyphicon glyphicon-triangle-bottom">
#                  </i>
#                 </a>
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                1
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA A40
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="6151/46068">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 13%">
#                  13%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="74 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 100%">
#                  100%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python Mem: 5696 Mib &lt;br/&gt; 运行时间: 1天11小时58分钟39秒">
#                  228220@
#                  <span class="user">
#                   zhaosm2022
#                  </span>
#                  (12%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
#                  <i class="glyphicon glyphicon-triangle-bottom">
#                  </i>
#                 </a>
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                2
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA A40
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="6151/46068">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 13%">
#                  13%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="78 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 100%">
#                  100%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python Mem: 5696 Mib &lt;br/&gt; 运行时间: 21小时54分钟57秒">
#                  221218@
#                  <span class="user">
#                   zhaosm2022
#                  </span>
#                  (12%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
#                  <i class="glyphicon glyphicon-triangle-bottom">
#                  </i>
#                 </a>
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                3
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA A40
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="6151/46068">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 13%">
#                  13%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="78 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 100%">
#                  100%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python Mem: 5696 Mib &lt;br/&gt; 运行时间: 1天11小时58分钟39秒">
#                  228224@
#                  <span class="user">
#                   zhaosm2022
#                  </span>
#                  (12%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
#                  <i class="glyphicon glyphicon-triangle-bottom">
#                  </i>
#                 </a>
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                4
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA A40
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="6151/46068">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 13%">
#                  13%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="76 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 100%">
#                  100%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python Mem: 5696 Mib &lt;br/&gt; 运行时间: 21小时54分钟57秒">
#                  221220@
#                  <span class="user">
#                   zhaosm2022
#                  </span>
#                  (12%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
#                  <i class="glyphicon glyphicon-triangle-bottom">
#                  </i>
#                 </a>
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                5
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA A40
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="33582/46068">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 72%">
#                  72%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="78 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 100%">
#                  100%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python Mem: 26354 Mib &lt;br/&gt; 运行时间: 14小时33分钟38秒">
#                  46211@
#                  <span class="user">
#                   zhouyk12023
#                  </span>
#                  (57%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
#                  <i class="glyphicon glyphicon-triangle-bottom">
#                  </i>
#                 </a>
#                </span>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python Mem: 6770 Mib &lt;br/&gt; 运行时间: 14小时30分钟57秒">
#                  60022@
#                  <span class="user">
#                   zhouyk12023
#                  </span>
#                  (14%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
#                  <i class="glyphicon glyphicon-triangle-bottom">
#                  </i>
#                 </a>
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                6
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA A40
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="14271/46068">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 30%">
#                  30%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="41 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 8%">
#                  8%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python Mem: 13816 Mib &lt;br/&gt; 运行时间: 02小时55分钟55秒">
#                  28181@
#                  <span class="user">
#                   shiyd2023
#                  </span>
#                  (29%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
#                  <i class="glyphicon glyphicon-triangle-bottom">
#                  </i>
#                 </a>
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                7
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA A40
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="989/46068">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 2%">
#                  2%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="56 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 68%">
#                  68%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python Mem: 534 Mib &lt;br/&gt; 运行时间: 36分钟43秒">
#                  175810@
#                  <span class="user">
#                   chengk
#                  </span>
#                  (1%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
#                  <i class="glyphicon glyphicon-triangle-bottom">
#                  </i>
#                 </a>
#                </span>
#               </td>
#              </tr>
#             </table>
#             <h4>
#              ai_gpu02
#              <small>
#               2024-09-21 15:36:02
#              </small>
#              (CPU:15.39% [13/80] MEM:80G/502G)
#             </h4>
#             <table class="table table-striped table-condensed">
#              <tr>
#               <th class="th-id">
#                #
#               </th>
#               <th class="th-name">
#                Name
#               </th>
#               <th class="th-mem">
#                Memory
#               </th>
#               <th class="th-usage">
#                GPU
#               </th>
#               <th class="th-processes">
#                <span class="hidden-xs">
#                 Processes
#                 <span class="label label-default">
#                  pid@user (RAM)
#                 </span>
#                </span>
#               </th>
#              </tr>
#              <tr>
#               <td>
#                0
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA A40
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="7887/46068">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 17%">
#                  17%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="45 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 47%">
#                  47%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python Mem: 7432 Mib &lt;br/&gt; 运行时间: 17小时39分钟54秒">
#                  60890@
#                  <span class="user">
#                   zhuyuchen530
#                  </span>
#                  (16%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
#                  <i class="glyphicon glyphicon-triangle-bottom">
#                  </i>
#                 </a>
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                1
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA A40
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="6909/46068">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 14%">
#                  14%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="40 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 53%">
#                  53%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python Mem: 6454 Mib &lt;br/&gt; 运行时间: 17小时39分钟54秒">
#                  60891@
#                  <span class="user">
#                   zhuyuchen530
#                  </span>
#                  (14%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
#                  <i class="glyphicon glyphicon-triangle-bottom">
#                  </i>
#                 </a>
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                2
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA A40
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="8265/46068">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 17%">
#                  17%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="42 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 63%">
#                  63%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python Mem: 7810 Mib &lt;br/&gt; 运行时间: 17小时39分钟54秒">
#                  60892@
#                  <span class="user">
#                   zhuyuchen530
#                  </span>
#                  (16%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
#                  <i class="glyphicon glyphicon-triangle-bottom">
#                  </i>
#                 </a>
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                3
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA A40
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="7427/46068">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 16%">
#                  16%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="42 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 47%">
#                  47%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python Mem: 6972 Mib &lt;br/&gt; 运行时间: 17小时39分钟54秒">
#                  60893@
#                  <span class="user">
#                   zhuyuchen530
#                  </span>
#                  (15%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
#                  <i class="glyphicon glyphicon-triangle-bottom">
#                  </i>
#                 </a>
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                4
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA A40
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="8203/46068">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 17%">
#                  17%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="42 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 66%">
#                  66%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python Mem: 7748 Mib &lt;br/&gt; 运行时间: 17小时39分钟54秒">
#                  60894@
#                  <span class="user">
#                   zhuyuchen530
#                  </span>
#                  (16%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
#                  <i class="glyphicon glyphicon-triangle-bottom">
#                  </i>
#                 </a>
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                5
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA A40
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="7281/46068">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 15%">
#                  15%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="43 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 69%">
#                  69%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python Mem: 6826 Mib &lt;br/&gt; 运行时间: 17小时39分钟54秒">
#                  60895@
#                  <span class="user">
#                   zhuyuchen530
#                  </span>
#                  (14%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
#                  <i class="glyphicon glyphicon-triangle-bottom">
#                  </i>
#                 </a>
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                6
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA A40
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="6901/46068">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 14%">
#                  14%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="40 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 55%">
#                  55%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python Mem: 6446 Mib &lt;br/&gt; 运行时间: 17小时39分钟54秒">
#                  60896@
#                  <span class="user">
#                   zhuyuchen530
#                  </span>
#                  (13%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
#                  <i class="glyphicon glyphicon-triangle-bottom">
#                  </i>
#                 </a>
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                7
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA A40
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="7399/46068">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 16%">
#                  16%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="42 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 58%">
#                  58%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python Mem: 6944 Mib &lt;br/&gt; 运行时间: 17小时39分钟54秒">
#                  60902@
#                  <span class="user">
#                   zhuyuchen530
#                  </span>
#                  (15%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
#                  <i class="glyphicon glyphicon-triangle-bottom">
#                  </i>
#                 </a>
#                </span>
#               </td>
#              </tr>
#             </table>
#             <h4>
#              ai_gpu03
#              <small>
#               2024-09-21 15:36:01
#              </small>
#              (CPU:12.87% [11/80] MEM:63G/502G)
#             </h4>
#             <table class="table table-striped table-condensed">
#              <tr>
#               <th class="th-id">
#                #
#               </th>
#               <th class="th-name">
#                Name
#               </th>
#               <th class="th-mem">
#                Memory
#               </th>
#               <th class="th-usage">
#                GPU
#               </th>
#               <th class="th-processes">
#                <span class="hidden-xs">
#                 Processes
#                 <span class="label label-default">
#                  pid@user (RAM)
#                 </span>
#                </span>
#               </th>
#              </tr>
#              <tr>
#               <td>
#                0
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA A40
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="8037/46068">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 17%">
#                  17%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="60 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 66%">
#                  66%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python3.1 Mem: 7582 Mib &lt;br/&gt; 运行时间: 05小时21分钟32秒">
#                  25346@
#                  <span class="user">
#                   jiangqi2022
#                  </span>
#                  (16%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
#                  <i class="glyphicon glyphicon-triangle-bottom">
#                  </i>
#                 </a>
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                1
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA A40
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="8037/46068">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 17%">
#                  17%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="58 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 58%">
#                  58%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python3.1 Mem: 7582 Mib &lt;br/&gt; 运行时间: 05小时21分钟32秒">
#                  25347@
#                  <span class="user">
#                   jiangqi2022
#                  </span>
#                  (16%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
# ...
#               </td>
#               <td>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python Mem: 2352 Mib &lt;br/&gt; 运行时间: 02小时23分钟36秒">
#                  43818@
#                  <span class="user">
#                   v-chenxch
#                  </span>
#                  (20%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
#                  <i class="glyphicon glyphicon-triangle-bottom">
#                  </i>
#                 </a>
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                5
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA GeForce RTX 2080 Ti
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="2614/11264">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 23%">
#                  23%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="51 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 37%">
#                  37%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python Mem: 2352 Mib &lt;br/&gt; 运行时间: 02小时23分钟36秒">
#                  43819@
#                  <span class="user">
#                   v-chenxch
#                  </span>
#                  (20%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
#                  <i class="glyphicon glyphicon-triangle-bottom">
#                  </i>
#                 </a>
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                6
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA GeForce RTX 2080 Ti
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="259/11264">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 2%">
#                  2%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="27 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 0%">
#                  0%
#                 </div>
#                </div>
#               </td>
#               <td>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                7
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA GeForce RTX 2080 Ti
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="259/11264">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 2%">
#                  2%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="29 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 0%">
#                  0%
#                 </div>
#                </div>
#               </td>
#               <td>
#               </td>
#              </tr>
#             </table>
#             <h4>
#              sist_gpu70
#              <small>
#               2024-09-21 15:36:01
#              </small>
#              (CPU:7.64% [4/48] MEM:15G/377G)
#             </h4>
#             <table class="table table-striped table-condensed">
#              <tr>
#               <th class="th-id">
#                #
#               </th>
#               <th class="th-name">
#                Name
#               </th>
#               <th class="th-mem">
#                Memory
#               </th>
#               <th class="th-usage">
#                GPU
#               </th>
#               <th class="th-processes">
#                <span class="hidden-xs">
#                 Processes
#                 <span class="label label-default">
#                  pid@user (RAM)
#                 </span>
#                </span>
#               </th>
#              </tr>
#              <tr>
#               <td>
#                0
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA GeForce RTX 2080 Ti
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="6895/11264">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 61%">
#                  61%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="59 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 100%">
#                  100%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <span class="hidden-xs process-content">
#                 <span class="process label label-primary" data-html="true" data-placement="top" data-toggle="tooltip" title="python3 Mem: 6632 Mib &lt;br/&gt; 运行时间: 01小时34分钟53秒">
#                  30903@
#                  <span class="user">
#                   xujw
#                  </span>
#                  (58%)
#                 </span>
#                </span>
#                <span class="visible-xs-inline">
#                 <a class="btn btn-default btn-xs btn-process" role="button" tabindex="0" type="button">
#                  <i class="glyphicon glyphicon-triangle-bottom">
#                  </i>
#                 </a>
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                1
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA GeForce RTX 2080 Ti
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="260/11264">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 2%">
#                  2%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="29 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 0%">
#                  0%
#                 </div>
#                </div>
#               </td>
#               <td>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                2
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA GeForce RTX 2080 Ti
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="260/11264">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 2%">
#                  2%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="25 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 0%">
#                  0%
#                 </div>
#                </div>
#               </td>
#               <td>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                3
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA GeForce RTX 2080 Ti
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="260/11264">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 2%">
#                  2%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="26 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 0%">
#                  0%
#                 </div>
#                </div>
#               </td>
#               <td>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                4
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA GeForce RTX 2080 Ti
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="260/11264">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 2%">
#                  2%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="26 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 0%">
#                  0%
#                 </div>
#                </div>
#               </td>
#               <td>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                5
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA GeForce RTX 2080 Ti
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="260/11264">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 2%">
#                  2%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="26 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 0%">
#                  0%
#                 </div>
#                </div>
#               </td>
#               <td>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                6
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA GeForce RTX 2080 Ti
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="260/11264">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 2%">
#                  2%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="23 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 0%">
#                  0%
#                 </div>
#                </div>
#               </td>
#               <td>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                7
#               </td>
#               <td>
#                <span class="hidden-xs">
#                 NVIDIA GeForce RTX 2080 Ti
#                </span>
#               </td>
#               <td>
#                <div class="progress progress-success" data-placement="top" data-toggle="tooltip" title="260/11264">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="11" class="progress-bar progress-bar-success progress-bar-striped" role="progressbar" style="width: 2%">
#                  2%
#                 </div>
#                </div>
#               </td>
#               <td>
#                <div class="progress progress-danger" data-placement="top" data-toggle="tooltip" title="26 °C">
#                 <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="92" class="progress-bar progress-bar-danger progress-bar-striped" role="progressbar" style="width: 0%">
#                  0%
#                 </div>
#                </div>
#               </td>
#               <td>
#               </td>
#              </tr>
#             </table>
#            </h3>
#           </h3>
#          </div>
#         </div>
#        </section>
#       </article>
#      </div>
#     </div>
#    </main>
#   </div>
#   <footer class="md-footer">
#    <div class="md-footer-meta md-typeset">
#     <div class="md-footer-meta__inner md-grid">
#      <div class="md-footer-copyright">
#       Created using
#       <a href="http://www.sphinx-doc.org/">
#        Sphinx
#       </a>
#       4.0.1.
# and
#       <a href="https://github.com/bashtage/sphinx-material/">
#        Material for
# Sphinx
#       </a>
#       <br/>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <script src="static/javascripts/application.js">
#   </script>
#   <script>
#    app.initialize({ version: "1.0.4", url: { base: ".." } })
#   </script>
#   <script type="text/javascript">
#    $(function () {
# $('[data-toggle="tooltip"]').tooltip();
# $('.btn-process').popover({
# placement: 'top',
# container: 'body',
# html: true,
# //selector: '[rel="popover"]', //Sepcify the selector here
# content: function () {
# var data = $(this).parent().parent().find(".process-content").html();
# if (data.trim() == "") data = "<small>No&nbsp;process</small>"
# return data;
# },
# trigger: "focus"
# });
# })
#   </script>
#  </body>
# </html>

# %%
def parse_gpu_info(soup):
    results = []
    nodes = soup.find_all('h4')
    
    for node in nodes:
        node_name = node.get_text().split()[0]
        table = node.find_next('table', class_='table table-striped table-condensed')
        if table:
            gpus = table.find_all('tr')[1:]  # Skip the header row
            for gpu in gpus:
                gpu_name = gpu.find_all('td')[1].get_text(strip=True)
                gpu_usage = gpu.find_all('td')[3].find('div', class_='progress-bar')['style'].split(':')[-1].strip()
                
                results.append({
                    'Node Name': node_name,
                    'GPU Model': gpu_name,
                    'GPU Usage': gpu_usage
                })
    
    return results

# %%
gpu_info = parse_gpu_info(soup)
for info in gpu_info:
    print(info)
# Out:
# {'Node Name': 'ai_gpu01', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '90%'}
# {'Node Name': 'ai_gpu01', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu01', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu01', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu01', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu01', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu01', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '8%'}
# {'Node Name': 'ai_gpu01', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '68%'}
# {'Node Name': 'ai_gpu02', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '47%'}
# {'Node Name': 'ai_gpu02', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '53%'}
# {'Node Name': 'ai_gpu02', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '63%'}
# {'Node Name': 'ai_gpu02', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '47%'}
# {'Node Name': 'ai_gpu02', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '66%'}
# {'Node Name': 'ai_gpu02', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '69%'}
# {'Node Name': 'ai_gpu02', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '55%'}
# {'Node Name': 'ai_gpu02', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '58%'}
# {'Node Name': 'ai_gpu03', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '66%'}
# {'Node Name': 'ai_gpu03', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '58%'}
# {'Node Name': 'ai_gpu03', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '62%'}
# {'Node Name': 'ai_gpu03', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '58%'}
# {'Node Name': 'ai_gpu03', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu03', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu03', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu03', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu04', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu04', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu04', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu04', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu04', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu04', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu04', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu04', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu05', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu05', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu05', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu05', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '60%'}
# {'Node Name': 'ai_gpu05', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu05', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu05', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu05', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu06', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu06', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu06', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu06', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu06', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '96%'}
# {'Node Name': 'ai_gpu06', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '96%'}
# {'Node Name': 'ai_gpu06', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu06', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '96%'}
# {'Node Name': 'ai_gpu07', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu07', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '99%'}
# {'Node Name': 'ai_gpu07', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '82%'}
# {'Node Name': 'ai_gpu07', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '82%'}
# {'Node Name': 'ai_gpu07', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu07', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '89%'}
# {'Node Name': 'ai_gpu07', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '78%'}
# {'Node Name': 'ai_gpu07', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu08', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu08', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu08', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu08', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu09', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '99%'}
# {'Node Name': 'ai_gpu09', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu09', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu09', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu10', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu10', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu10', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu10', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '35%'}
# {'Node Name': 'ai_gpu11', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu11', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu11', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu11', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu12', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu12', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '2%'}
# {'Node Name': 'ai_gpu12', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '62%'}
# {'Node Name': 'ai_gpu13', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu13', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu13', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu13', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu14', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '21%'}
# {'Node Name': 'ai_gpu14', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '23%'}
# {'Node Name': 'ai_gpu14', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu14', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu15', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '93%'}
# {'Node Name': 'ai_gpu15', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu15', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu15', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu16', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '35%'}
# {'Node Name': 'ai_gpu16', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '45%'}
# {'Node Name': 'ai_gpu16', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '33%'}
# {'Node Name': 'ai_gpu16', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '33%'}
# {'Node Name': 'ai_gpu17', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu17', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu17', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu17', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu18', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu18', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '33%'}
# {'Node Name': 'ai_gpu18', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '47%'}
# {'Node Name': 'ai_gpu18', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu19', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu19', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '46%'}
# {'Node Name': 'ai_gpu19', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '48%'}
# {'Node Name': 'ai_gpu19', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu20', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu20', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '66%'}
# {'Node Name': 'ai_gpu20', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu20', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu21', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '82%'}
# {'Node Name': 'ai_gpu21', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu21', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '94%'}
# {'Node Name': 'ai_gpu21', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu22', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '32%'}
# {'Node Name': 'ai_gpu22', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '38%'}
# {'Node Name': 'ai_gpu22', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '36%'}
# {'Node Name': 'ai_gpu22', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '40%'}
# {'Node Name': 'ai_gpu23', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '70%'}
# {'Node Name': 'ai_gpu23', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '78%'}
# {'Node Name': 'ai_gpu23', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu23', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '90%'}
# {'Node Name': 'ai_gpu24', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu24', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu24', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu24', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu25', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu25', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '1%'}
# {'Node Name': 'ai_gpu25', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '93%'}
# {'Node Name': 'ai_gpu25', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '7%'}
# {'Node Name': 'ai_gpu26', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '22%'}
# {'Node Name': 'ai_gpu26', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu26', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '94%'}
# {'Node Name': 'ai_gpu26', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '58%'}
# {'Node Name': 'ai_gpu27', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '97%'}
# {'Node Name': 'ai_gpu27', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '26%'}
# {'Node Name': 'ai_gpu27', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu27', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu28', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu28', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '95%'}
# {'Node Name': 'ai_gpu28', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu28', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu29', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu29', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '97%'}
# {'Node Name': 'ai_gpu29', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu29', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu30', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '93%'}
# {'Node Name': 'ai_gpu30', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu30', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '95%'}
# {'Node Name': 'ai_gpu30', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu31', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu31', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu32', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu32', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu32', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu32', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu33', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '35%'}
# {'Node Name': 'ai_gpu33', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '54%'}
# {'Node Name': 'ai_gpu33', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '0%'}
# {'Node Name': 'ai_gpu33', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '59%'}
# {'Node Name': 'ai_gpu34', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu34', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu34', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu34', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '100%'}
# {'Node Name': 'ai_gpu35', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '58%'}
# {'Node Name': 'ai_gpu35', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '72%'}
# {'Node Name': 'ai_gpu35', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '49%'}
# {'Node Name': 'ai_gpu35', 'GPU Model': 'NVIDIA TITAN RTX', 'GPU Usage': '72%'}
# {'Node Name': 'sist-a40-06', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '0%'}
# {'Node Name': 'sist-a40-06', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '97%'}
# {'Node Name': 'sist-a40-06', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'sist-a40-06', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'sist-a40-06', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'sist-a40-06', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '0%'}
# {'Node Name': 'sist-a40-06', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '0%'}
# {'Node Name': 'sist-a40-06', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'sist-a40-07', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '71%'}
# {'Node Name': 'sist-a40-07', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '75%'}
# {'Node Name': 'sist-a40-07', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'sist-a40-07', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '72%'}
# {'Node Name': 'sist-a40-07', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '76%'}
# {'Node Name': 'sist-a40-07', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'sist-a40-07', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'sist-a40-07', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '100%'}
# {'Node Name': 'sist-a40-08', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '71%'}
# {'Node Name': 'sist-a40-08', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '72%'}
# {'Node Name': 'sist-a40-08', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '69%'}
# {'Node Name': 'sist-a40-08', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '73%'}
# {'Node Name': 'sist-a40-08', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '72%'}
# {'Node Name': 'sist-a40-08', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '74%'}
# {'Node Name': 'sist-a40-08', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '68%'}
# {'Node Name': 'sist-a40-08', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '72%'}
# {'Node Name': 'sist-a40-09', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '0%'}
# {'Node Name': 'sist-a40-09', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '0%'}
# {'Node Name': 'sist-a40-09', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '0%'}
# {'Node Name': 'sist-a40-09', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '0%'}
# {'Node Name': 'sist-a40-09', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '0%'}
# {'Node Name': 'sist-a40-09', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '0%'}
# {'Node Name': 'sist-a40-09', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '0%'}
# {'Node Name': 'sist-a40-09', 'GPU Model': 'NVIDIA A40', 'GPU Usage': '1%'}
# {'Node Name': 'sist_gpu36', 'GPU Model': 'Tesla V100-PCIE-16GB', 'GPU Usage': '100%'}
# {'Node Name': 'sist_gpu36', 'GPU Model': 'Tesla V100-PCIE-16GB', 'GPU Usage': '100%'}
# {'Node Name': 'sist_gpu36', 'GPU Model': 'Tesla V100-PCIE-16GB', 'GPU Usage': '100%'}
# {'Node Name': 'sist_gpu36', 'GPU Model': 'Tesla V100-PCIE-16GB', 'GPU Usage': '100%'}
# {'Node Name': 'sist_gpu48', 'GPU Model': 'NVIDIA TITAN V', 'GPU Usage': '100%'}
# {'Node Name': 'sist_gpu48', 'GPU Model': 'NVIDIA TITAN V', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu48', 'GPU Model': 'NVIDIA TITAN V', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu48', 'GPU Model': 'NVIDIA TITAN V', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu49', 'GPU Model': 'NVIDIA TITAN V', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu49', 'GPU Model': 'NVIDIA TITAN V', 'GPU Usage': '95%'}
# {'Node Name': 'sist_gpu49', 'GPU Model': 'NVIDIA TITAN V', 'GPU Usage': '83%'}
# {'Node Name': 'sist_gpu49', 'GPU Model': 'NVIDIA TITAN V', 'GPU Usage': '96%'}
# {'Node Name': 'sist_gpu53', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu53', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu53', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu53', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu54', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu54', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu54', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu54', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu55', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu55', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu55', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu55', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu56', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu56', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu56', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu56', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu57', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu57', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu57', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu57', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu58', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu58', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu58', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu58', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu59', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu59', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu59', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu59', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu60', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu60', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu60', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu60', 'GPU Model': 'NVIDIA GeForce GTX 1080', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu61', 'GPU Model': 'NVIDIA TITAN X (Pascal)', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu61', 'GPU Model': 'NVIDIA TITAN X (Pascal)', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu61', 'GPU Model': 'NVIDIA TITAN X (Pascal)', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu61', 'GPU Model': 'NVIDIA TITAN X (Pascal)', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu62', 'GPU Model': 'NVIDIA TITAN X (Pascal)', 'GPU Usage': '99%'}
# {'Node Name': 'sist_gpu62', 'GPU Model': 'NVIDIA TITAN X (Pascal)', 'GPU Usage': '100%'}
# {'Node Name': 'sist_gpu62', 'GPU Model': 'NVIDIA TITAN X (Pascal)', 'GPU Usage': '82%'}
# {'Node Name': 'sist_gpu62', 'GPU Model': 'NVIDIA TITAN X (Pascal)', 'GPU Usage': '82%'}
# {'Node Name': 'sist_gpu63', 'GPU Model': 'Tesla M40 24GB', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu63', 'GPU Model': 'Tesla M40 24GB', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu63', 'GPU Model': 'Tesla M40 24GB', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu63', 'GPU Model': 'Tesla M40 24GB', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu64', 'GPU Model': 'Tesla M40 24GB', 'GPU Usage': '100%'}
# {'Node Name': 'sist_gpu64', 'GPU Model': 'Tesla M40 24GB', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu64', 'GPU Model': 'Tesla M40 24GB', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu64', 'GPU Model': 'Tesla M40 24GB', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu65', 'GPU Model': 'Tesla M40 24GB', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu65', 'GPU Model': 'Tesla M40 24GB', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu65', 'GPU Model': 'Tesla M40 24GB', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu66', 'GPU Model': 'Tesla M40 24GB', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu66', 'GPU Model': 'Tesla M40 24GB', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu66', 'GPU Model': 'Tesla M40 24GB', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu66', 'GPU Model': 'Tesla M40 24GB', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu67', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu67', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu67', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu67', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu68', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '90%'}
# {'Node Name': 'sist_gpu68', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu68', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu68', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu69', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '85%'}
# {'Node Name': 'sist_gpu69', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu69', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '43%'}
# {'Node Name': 'sist_gpu69', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '43%'}
# {'Node Name': 'sist_gpu69', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '37%'}
# {'Node Name': 'sist_gpu69', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '37%'}
# {'Node Name': 'sist_gpu69', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu69', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu70', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '100%'}
# {'Node Name': 'sist_gpu70', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu70', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu70', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu70', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu70', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu70', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}
# {'Node Name': 'sist_gpu70', 'GPU Model': 'NVIDIA GeForce RTX 2080 Ti', 'GPU Usage': '0%'}

# %%
from collections import defaultdict
def classify_by_gpu_model(gpu_info):
    classified_info = defaultdict(list)
    
    for info in gpu_info:
        gpu_model = info['GPU Model']
        gpu_usage = info['GPU Usage']
        
        if gpu_usage == '0%':
            classified_info[gpu_model].append(info['Node Name'])
    
    return classified_info


classified_info = classify_by_gpu_model(gpu_info)
   
print("空闲节点列表:")     
for gpu_model, nodes in classified_info.items():
    print(f"GPU Model: {gpu_model}")
    print(f"Nodes with 0% GPU Usage: {', '.join(nodes)}\n")
# Out:
# 空闲节点列表:
# GPU Model: NVIDIA A40
# Nodes with 0% GPU Usage: ai_gpu03, ai_gpu05, ai_gpu05, ai_gpu07, ai_gpu09, ai_gpu10, sist-a40-06, sist-a40-06, sist-a40-06, sist-a40-09, sist-a40-09, sist-a40-09, sist-a40-09, sist-a40-09, sist-a40-09, sist-a40-09
#
# GPU Model: NVIDIA GeForce RTX 2080 Ti
# Nodes with 0% GPU Usage: ai_gpu14, ai_gpu14, ai_gpu15, ai_gpu15, ai_gpu17, ai_gpu17, ai_gpu17, ai_gpu18, ai_gpu19, ai_gpu20, ai_gpu20, ai_gpu20, ai_gpu21, ai_gpu21, ai_gpu23, ai_gpu24, ai_gpu24, ai_gpu24, ai_gpu24, sist_gpu67, sist_gpu67, sist_gpu67, sist_gpu67, sist_gpu68, sist_gpu68, sist_gpu68, sist_gpu69, sist_gpu69, sist_gpu69, sist_gpu70, sist_gpu70, sist_gpu70, sist_gpu70, sist_gpu70, sist_gpu70, sist_gpu70
#
# GPU Model: NVIDIA TITAN RTX
# Nodes with 0% GPU Usage: ai_gpu26, ai_gpu27, ai_gpu28, ai_gpu28, ai_gpu28, ai_gpu29, ai_gpu29, ai_gpu29, ai_gpu31, ai_gpu31, ai_gpu32, ai_gpu32, ai_gpu32, ai_gpu32, ai_gpu33
#
# GPU Model: NVIDIA TITAN V
# Nodes with 0% GPU Usage: sist_gpu48, sist_gpu48, sist_gpu48, sist_gpu49
#
# GPU Model: NVIDIA GeForce GTX 1080
# Nodes with 0% GPU Usage: sist_gpu53, sist_gpu53, sist_gpu53, sist_gpu53, sist_gpu54, sist_gpu54, sist_gpu54, sist_gpu54, sist_gpu55, sist_gpu55, sist_gpu55, sist_gpu55, sist_gpu56, sist_gpu56, sist_gpu56, sist_gpu56, sist_gpu57, sist_gpu57, sist_gpu57, sist_gpu57, sist_gpu58, sist_gpu58, sist_gpu58, sist_gpu58, sist_gpu59, sist_gpu59, sist_gpu59, sist_gpu59, sist_gpu60, sist_gpu60, sist_gpu60, sist_gpu60
#
# GPU Model: NVIDIA TITAN X (Pascal)
# Nodes with 0% GPU Usage: sist_gpu61, sist_gpu61, sist_gpu61, sist_gpu61
#
# GPU Model: Tesla M40 24GB
# Nodes with 0% GPU Usage: sist_gpu63, sist_gpu63, sist_gpu63, sist_gpu63, sist_gpu64, sist_gpu64, sist_gpu64, sist_gpu65, sist_gpu65, sist_gpu65, sist_gpu66, sist_gpu66, sist_gpu66, sist_gpu66
